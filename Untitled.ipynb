# %%
import sys
from pathlib import Path

sys.path.append(str(Path(__file__).resolve().parent))

from src.data_ingestion.load_data import df
from src.data_cleaning.clean_data import clean_data
from src.feature_engineering.feature_engineering import engineer_features

df_clean = clean_data(df)
df_features = engineer_features(df_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 from pathlib import Path
# ----> 4 sys.path.append(str(Path(__file__).resolve().parent))
#       6 from src.data_ingestion.load_data import df
#       7 from src.data_cleaning.clean_data import clean_data
#
# NameError: name '__file__' is not defined
